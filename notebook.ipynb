# %%
import pandas as pd

# %%
df=pd.read_excel("data_science.xlsx")

# %%
df.head(10)
# Out:
#    Unnamed: 0  sr    name  age  salary
# 0         NaN   1   nasir   11    5500
# 1         NaN   2    mmnd   22    6600
# 2         NaN   3     dog   11    7500
# 3         NaN   4   water   11    4300
# 4         NaN   5     log   43    4200
# 5         NaN   6   waist   54    2278
# 6         NaN   7     jar   65    8800
# 7         NaN   8   forum   45    4536
# 8         NaN   9  joging   43    2788
# 9         NaN  10  assign   36    1937

# %%
df.tail(2)
# Out:
#     Unnamed: 0  sr   name  age  salary
# 24         NaN  25  waqas   34      71
# 25         NaN  26  arham   25      89

# %%
df.shape
# Out:
# (26, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   sr          26 non-null     int64
#  2   name        26 non-null     str
#  3   age         26 non-null     int64
#  4   salary      26 non-null     int64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 1.1 KB

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.3 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.1 MB 1.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/8.1 MB 1.3 MB/s eta 0:00:06
#    ------ --------------------------------- 1.3/8.1 MB 1.3 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.1 MB 1.3 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/8.1 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.1 MB 1.3 MB/s eta 0:00:05
#    ------------ --------------------------- 2.6/8.1 MB 1.3 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.1 MB 1.3 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.1 MB 1.3 MB/s eta 0:00:04
# ...
